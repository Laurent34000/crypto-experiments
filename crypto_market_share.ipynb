# %% [markdown]
# <h1 style="text-align:center;">TOP 10 CRYPO MARKET SHARE</h1>
# <h2>Welcome to my Jupyter Notebook project, where I’ll be using the CoinGecko API to display the top 10 cryptocurrencies by market share.</h2>

# %% [markdown]
# #### Initially, we will present the results in a table format

# %%
import requests
import pandas as pd

url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=10&page=1&sparkline=false%27"

 
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)
table = df[['name', 'market_cap']]

table.head(10)
# Out:
#                 name     market_cap
# 0            Bitcoin  1205130081016
# 1           Ethereum   290031750163
# 2             Tether   119591787818
# 3                BNB    79042363801
# 4             Solana    67242410894
# 5               USDC    35459272908
# 6                XRP    32403364458
# 7  Lido Staked Ether    23636257373
# 8           Dogecoin    15271032468
# 9            Toncoin    13641889418

# %% [markdown]
# #### Next, we'll visualize the results using a pie chart created with the Matplotlib library

# %%
import matplotlib.pyplot as plt

token = df['name']
market_cap = df['market_cap']

plt.figure(figsize=(8,8))

plt.pie(market_cap, labels=token,wedgeprops={'edgecolor': 'black'}, autopct="%2.0f%%")
plt.title("TOP 10 MARKET CAP")
plt.legend(title="Tokens",bbox_to_anchor=(1,0,0.5,1))

plt.show()
